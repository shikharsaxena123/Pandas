# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.DataFrame({
    "Name": ["Rajesh", "Piyush", "Kaleem", "Harsh", "Rajat"],
    "Age" : [54, 53, 27, 28, 24],
    "Sex" : ["Male", "Female", "Male", "Female", "Male"]
})

df
# Out:
#      Name  Age     Sex
# 0  Rajesh   54    Male
# 1  Piyush   53  Female
# 2  Kaleem   27    Male
# 3   Harsh   28  Female
# 4   Rajat   24    Male
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(df, *['Age'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
# ...

# %%
df["Age"]
# Out:
# 0    54
# 1    53
# 2    27
# 3    28
# 4    24
# Name: Age, dtype: int64

# %%
ages = pd.Series([54, 53, 27, 28, 24], name = "Age")
ages
# Out:
# 0    54
# 1    53
# 2    27
# 3    28
# 4    24
# Name: Age, dtype: int64

# %%
df["Age"].max()
# Out:
# 54

# %%
ages.max()
# Out:
# 54

# %%
df.describe()
# Out:
#              Age
# count   5.000000
# mean   37.200000
# std    14.956604
# min    24.000000
# 25%    27.000000
# 50%    28.000000
# 75%    53.000000
# max    54.000000
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_2, *['Age'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
# ...
